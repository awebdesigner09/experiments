# %%
# %pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Import TensorFlow into jupyter notebook
import tensorflow as tf
import tensorflow_hub as hub
print("TF version: ", tf.__version__)
print("TF Hub version: ", hub.__version__)

# Check for GPU availability
print("GPU", "available (YESSSSSS!!!!!!!)" if tf.config.list_physical_devices("GPU") else "not available :()")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Import TensorFlow into jupyter notebook
# ----> 2 import tensorflow as tf
#       3 import tensorflow_hub as hub
#       4 print("TF version: ", tf.__version__)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !nvidia-smi
# Out:
# Fri Feb 14 09:15:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.42                 Driver Version: 572.42         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P0             31W /  150W |       0MiB /  16376MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics wget
# %pip install clearml
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75  Python-3.13.2 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
# Setup complete  (32 CPUs, 63.7 GB RAM, 13.8/3726.0 GB disk)

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
# Configuration file already exists: C:\Users\awebd\clearml.conf
# Leaving setup, feel free to edit the configuration file.

# %%
import wget 

wget.download('https://www.dropbox.com/s/qvglw8pqo16769f/pothole_dataset_v8.zip?dl=1')
# Out:
# 'pothole_dataset_v8.zip'

# %%
# !tar -xf pothole_dataset_v8.zip

# %%
from ultralytics import YOLO

# Load the model.
model = YOLO('yolo11n.pt')

# Training.
results = model.train(
   data='pothole_v8.yaml',
   imgsz=1280,
   epochs=50,
   batch=8,
   name='yolo11n_50epochs'
)
# Out:
# Ultralytics 8.3.75  Python-3.13.2 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
# ...

# %%
# pip uninstall torch torchvision torchaudio
# pip --timeout=1000000  install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu126

# %%
import wget

# %%
wget.download('https://github.com/AnoopCA/YOLOv8_Custom_Dataset_Pothole_Detection/raw/refs/heads/master/Pothole.mp4')
# Out:
# 'Pothole.mp4'

# %%
# !yolo task=detect mode=predict model=D:/Work/experiments/runs/detect/yolo11n_50epochs6/weights/best.pt source=Pothole.mp4 show=True imgsz=1280 name=yolo11n_50e show_labels=False
# Out:
# Ultralytics 8.3.75 🚀 Python-3.13.2 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 8 potholes, 34.6ms
# video 1/1 (frame 2/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 12 potholes, 5.3ms
# video 1/1 (frame 3/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 13 potholes, 5.3ms
# video 1/1 (frame 4/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 11 potholes, 5.2ms
# video 1/1 (frame 5/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 12 potholes, 5.1ms
# video 1/1 (frame 6/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 13 potholes, 5.2ms
# video 1/1 (frame 7/692) d:\work\experiments\YOLO-CustomData\Pothole.mp4: 736x1280 14 potholes, 5.2ms
# ...

# %%
import torch
from ultralytics import YOLO
import cv2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import torch
from ultralytics import YOLO
import cv2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
video_path = 'Pothole.mp4'
video_path_out = '{}_out.mp4'.format(video_path[:-4])
model_path = 'D:/Work/experiments/runs/detect/yolo11n_50epochs6/weights/best.pt'

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

# Load a model
model = YOLO(model_path).to(device)
threshold = 0.5

while ret:
    results = model(frame)[0]
    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result
        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 2)
            cv2.putText(frame, results.names[int(class_id)].capitalize(), (int(x1), int(y1 - 10)), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 0, 255), 2)

    cv2.imshow('Pothole detection', frame)
    cv2.waitKey(1)
    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 736x1280 8 potholes, 24.2ms
# Speed: 4.6ms preprocess, 24.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 12 potholes, 22.3ms
# Speed: 3.3ms preprocess, 22.3ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 13 potholes, 16.4ms
# Speed: 3.0ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 11 potholes, 16.4ms
# Speed: 3.1ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 12 potholes, 16.5ms
# Speed: 3.1ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 13 potholes, 16.4ms
# Speed: 3.4ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 14 potholes, 16.4ms
# Speed: 3.5ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 12 potholes, 15.7ms
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/yolov8n_v8_50e/weights/best.pt name=yolov8n_eval data=pothole_v8.yaml imgsz=1280
